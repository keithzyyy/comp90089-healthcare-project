# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt



from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score, average_precision_score, classification_report

from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import RandomOverSampler


from sklearn.linear_model import LogisticRegression

# %% [markdown]
# I (Keith) use sklearn: 1.4.2 imblearn: 0.12.3

# %%
import sklearn, imblearn
print("sklearn:", sklearn.__version__, "imblearn:", imblearn.__version__)
# Out:
# sklearn: 1.2.2 imblearn: 0.11.0

# %% [markdown]
# # Keep this random state

# %%
RANDOM_STATE=42

# %% [markdown]
# # Splitting functions and custom IQRClipper

# %%
# Convert one-hot cohort flags into a single label
def label_subcohort(df):
    df = df.copy()
    df["cohort"] = np.select(
        [
            df["is_mi"] == 1,
            df["is_pcr"] == 1,
            df["is_cbs"] == 1
        ],
        ["MI", "PCI", "CABG"],
        default="Other"
    )
    return df

# 1) collapse race to a few stable bins
def collapse_race(r):
    if pd.isna(r): return "UNKNOWN/OTHER"
    r = str(r).upper()
    if r.startswith("WHITE"): return "WHITE"
    if r.startswith("BLACK"): return "BLACK"
    if r.startswith("ASIAN"): return "ASIAN"
    if "HISPANIC" in r:        return "HISPANIC"
    if "PORTUGUESE" in r:      return "PORTUGUESE"
    if "SOUTH AMERICAN" in r:  return "HISPANIC"  # sensible merge
    if "PACIFIC ISLANDER" in r:return "PACIFIC"
    if r in {"OTHER","UNKNOWN","UNABLE TO OBTAIN","PATIENT DECLINED TO ANSWER",
             "MULTIPLE RACE/ETHNICITY","AMERICAN INDIAN/ALASKA NATIVE",
             "WHITE - OTHER EUROPEAN","WHITE - EASTERN EUROPEAN","WHITE - RUSSIAN",
             "WHITE - BRAZILIAN","BLACK/CAPE VERDEAN","BLACK/CARIBBEAN ISLAND"}:
        return "UNKNOWN/OTHER"
    return "UNKNOWN/OTHER"

def build_subject_strata(df: pd.DataFrame,
                         min_bin_size: int = 5,
                         outcome_col: str = "y",
                         cohort_col: str = "cohort",
                         race_col: str = "race"):
    
    g = df.copy()
    
    g["race_collapsed"] = g[race_col].map(collapse_race)

    # Make a *stable* per-subject cohort label.
    # Option A: majority cohort across their stays
    subj_mode_cohort = (
        g.groupby(["subject_id", cohort_col]).size()
         .reset_index(name="n")
         .sort_values(["subject_id","n"], ascending=[True, False])
         .drop_duplicates("subject_id")[["subject_id", cohort_col]]
         .rename(columns={cohort_col: "cohort_major"})
    )

    # Outcome as a subject-level flag (any positive stay)
    subj_y = (
        g.groupby("subject_id")[outcome_col]
         .max()
         .rename("y_any")
         .reset_index()
    )

    # Subject-level collapsed race: mode
    subj_race = (
        g.groupby(["subject_id","race_collapsed"]).size()
         .reset_index(name="n")
         .sort_values(["subject_id","n"], ascending=[True, False])
         .drop_duplicates("subject_id")[["subject_id","race_collapsed"]]
    )

    subj = (
        subj_mode_cohort.merge(subj_race, on="subject_id")
                        .merge(subj_y, on="subject_id")
    )

    # Compose strata label; you can add age bands, etc., if you want more control
    subj["strata"] = (
        subj["cohort_major"].astype(str) + "|" +
        subj["race_collapsed"].astype(str) + "|" +
        subj["y_any"].astype(str)
    )

    # Merge rare strata into a single bin to avoid stratify errors
    counts = subj["strata"].value_counts()
    rare = counts[counts < min_bin_size].index
    subj.loc[subj["strata"].isin(rare), "strata"] = "OTHER_BIN"

    return subj[["subject_id","strata"]]

def remove_outlier_drop_gapdays_and_split(df_all: pd.DataFrame,
                                          val_and_test_size: float = 0.30,
                                          random_state: int = 42,
                                          outcome_col: str = "y",
                                          cohort_col: str = "cohort",
                                          race_col: str = "race"):
    """
    - Hard-remove obvious data-entry outliers.
    - Drop prev_gap_days (non-imputable by design).
    - Stratified split by *subject_id* using a patient-level strata label
      (cohort_major × collapsed race × y_any), with rare bins merged.
    - Returns row-level train/val/test DataFrames.
    """
    
    
    df = df_all.copy()
    if "cohort" not in df.columns:
        df = label_subcohort(df)

    # 0) hard outliers + drop prev_gap_days
    df = df[(df["glucose_mean"] < 999999) & (df["wbc_last_24h"] < 400)]
    if "prev_gap_days" in df.columns:
        df = df.drop(columns=["prev_gap_days"])

    # 1) build subject-level strata
    subj = build_subject_strata(df, min_bin_size=5,
                                outcome_col=outcome_col,
                                cohort_col=cohort_col,
                                race_col=race_col)

    # 2) split BY subject IDs into train vs temp (val+test) with stratify
    train_ids, temp_ids = train_test_split(
        subj["subject_id"].values,
        test_size=val_and_test_size,
        random_state=random_state,
        stratify=subj["strata"].values
    )

    # 3) from the temp pool, split val vs test (50/50) with stratify again
    temp = subj[subj["subject_id"].isin(temp_ids)]
    val_ids, test_ids = train_test_split(
        temp["subject_id"].values,
        test_size=0.5,
        random_state=random_state,
        stratify=temp["strata"].values
    )

    # 4) map IDs back to rows
    train_df = df[df["subject_id"].isin(train_ids)].copy()
    val_df   = df[df["subject_id"].isin(val_ids)].copy()
    test_df  = df[df["subject_id"].isin(test_ids)].copy()

    # Optional sanity checks
    for s in ["train","val","test"]:
        print(s, df[df.subject_id.isin(eval(f"{s}_ids"))][outcome_col].mean())

    return train_df, val_df, test_df


def examine_splits(df, df_type='train'):
    print('-'*25, f'EXAMINING {df_type} data', '-'*25)
    print(f'{df_type} data has {df.shape[0]} ICU stays across {df.subject_id.nunique()} patients.')
    print('-'*25, 'EXAMINE FIRST FEW INSTANCES', '-'*25)
    display(df.head())
    
    print('-'*25, 'CLASS DISTRIBUTION (%)', '-'*25)
    display(df.y.value_counts(normalize=True)*100)
    
    print('-'*25, f'RACE DISTRIBUTION (%) ({df.race.nunique()} races)', '-'*25)
    display(df.race.value_counts(normalize=True)*100)
    
    print('-'*25, 'COHORT DISTRIBUTION (%)', '-'*25)
    display(df.cohort.value_counts(normalize=True)*100)
    
    print('-'*25, 'AGE DISTRIBUTION', '-'*25)
    df.hist('age')


class IQRClipper(BaseEstimator, TransformerMixin):
    """
    Clips feature values based on the Interquartile Range (IQR).
    Values below Q1 - factor*IQR are set to that lower bound,
    and values above Q3 + factor*IQR are set to that upper bound.

    Parameters
    ----------
    factor : float, default=1.5
        Multiplier for the IQR range.
    """

    def __init__(self, factor=1.5):
        self.factor = factor

    def fit(self, X, y=None):
        X_df = pd.DataFrame(X)
        Q1 = X_df.quantile(0.25)
        Q3 = X_df.quantile(0.75)
        IQR = Q3 - Q1
        self.lower_bounds_ = Q1 - self.factor * IQR
        self.upper_bounds_ = Q3 + self.factor * IQR
        return self

    def transform(self, X):
        X_df = pd.DataFrame(X)
        X_clipped = X_df.clip(lower=self.lower_bounds_, upper=self.upper_bounds_, axis=1)
        # Return as same type as input
        return X_clipped if isinstance(X, pd.DataFrame) else X_clipped.to_numpy()

# %% [markdown]
# # REMOVE OBVIOUS OUTLIERS, DROP COLUMNS, THEN SPLIT

# %%
# REMOVE OBVIOUS OUTLIERS, DROP COLUMNS, THEN SPLIT

df = pd.read_csv("merged_chd_model_v2.csv")

train_df, val_df, test_df = remove_outlier_drop_gapdays_and_split(
    df,
    val_and_test_size = 0.3,
    random_state=RANDOM_STATE,
    outcome_col='y',
    cohort_col='cohort',
    race_col='race'
)
# Out:
# train 0.058043273753527753
# val 0.06519823788546256
# test 0.05415002219263205

# %% [markdown]
# Run this to see the distribution of train, val, and test splits

# %%
# examine_splits(train_df, df_type='train')
# examine_splits(val_df, df_type='val')
# examine_splits(test_df, df_type='test')

# %% [markdown]
# # 0. DROP IDENTIFIERS AND PREP THE DATA FOR HYPERPARAMETER TUNING

# %%
# 0. DROP IDENTIFIERS AND PREP THE DATA FOR HYPERPARAMETER TUNING

# Columns to drop from X
ID_COLS = ["subject_id", "hadm_id", "stay_id", "is_mi", "is_pcr", "is_cbs"]
DROP_COLS = [c for c in (ID_COLS + ["y"]) if c in train_df.columns]

# Build X_all / y_all and derive feature lists FROM X_all
X_all = pd.concat([train_df, val_df], axis=0).reset_index(drop=True).drop(columns=DROP_COLS)
y_all = pd.concat([train_df, val_df], axis=0).reset_index(drop=True)["y"]


# define numeric / categorical feature sets
numeric_cols = X_all.select_dtypes(include=["number"]).columns.tolist()
categorical_cols = [c for c in X_all.columns if c not in numeric_cols]

# %% [markdown]
# # 1. DEFINE THE PIPELINE (PREPROCESSING & OVERSAMPLING & MODELLING)
#
# To swap models, change the final pipeline step from LogisticRegression to your own estimator (e.g. MLP via scikeras). Keep preprocessing identical.

# %%
import pandas as pd
import numpy as np
from xgboost import XGBClassifier
from sklearn.pipeline import Pipeline
from imblearn.pipeline import Pipeline as ImbPipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import (
    accuracy_score, confusion_matrix, average_precision_score,
    roc_auc_score, classification_report
)


num_pipe = Pipeline([
    ("iqr_clip", IQRClipper(factor=1.5)),
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

cat_pipe = Pipeline([
    ("imputer", SimpleImputer(strategy="most_frequent")),
    ("ohe", OneHotEncoder(handle_unknown="ignore"))
])

preprocessor = ColumnTransformer(
    transformers=[
        ("num", num_pipe, numeric_cols),
        ("cat", cat_pipe, categorical_cols),
    ],
    remainder="drop"
)


X_train = train_df.drop(columns=ID_COLS + ["y"])
y_train = train_df["y"]

X_val = val_df.drop(columns=ID_COLS + ["y"])
y_val = val_df["y"]


neg = (y_train == 0).sum()
pos = (y_train == 1).sum()
spw = neg / max(pos, 1)


X_train_processed = preprocessor.fit_transform(X_train)
X_val_processed   = preprocessor.transform(X_val)


model = XGBClassifier(
    n_estimators=500,
    max_depth=8,
    learning_rate=0.01,
    subsample=0.8,
    colsample_bytree=0.9,
    min_child_weight=1.0,
    reg_lambda=1.0,
    objective="binary:logistic",
    eval_metric=["auc", "aucpr"],
    scale_pos_weight=spw,
    tree_method="hist",
    n_jobs=-1,
    random_state=RANDOM_STATE
)

model.fit(
    X_train_processed,
    y_train,
    eval_set=[(X_val_processed, y_val)],
    verbose=True
)


pipe = ImbPipeline(steps=[
    ("pre", preprocessor),
    ("model", model)
])

pipe.fit(X_train, y_train)  


eval_result = model.evals_result()


for i in range(1, model.get_params()["n_estimators"] + 1):
    y_pred_proba = model.predict_proba(X_train_processed, iteration_range=(0, i))[:, 1]
    y_pred_label = (y_pred_proba >= 0.5).astype(int)

    acc = accuracy_score(y_train, y_pred_label)
    auc = eval_result["validation_0"]["auc"][i - 1]
    aucpr = eval_result["validation_0"]["aucpr"][i - 1]
    tn, fp, fn, tp = confusion_matrix(y_train, y_pred_label).ravel()

    print(f"Round {i:03d}: "
          f"Acc = {acc:.4f} | "
          f"AUC = {auc:.4f} | "
          f"AUC-PR = {aucpr:.4f} | "
          f"TP = {tp}, FP = {fp}, TN = {tn}, FN = {fn}")
# Out:
# [0]	validation_0-auc:0.60156	validation_0-aucpr:0.10508
# [1]	validation_0-auc:0.67273	validation_0-aucpr:0.12450
# [2]	validation_0-auc:0.68259	validation_0-aucpr:0.13485
# [3]	validation_0-auc:0.68845	validation_0-aucpr:0.14109
# [4]	validation_0-auc:0.68682	validation_0-aucpr:0.14670
# [5]	validation_0-auc:0.68882	validation_0-aucpr:0.15616
# [6]	validation_0-auc:0.68992	validation_0-aucpr:0.16967
# [7]	validation_0-auc:0.69311	validation_0-aucpr:0.15656
# [8]	validation_0-auc:0.70228	validation_0-aucpr:0.15319
# [9]	validation_0-auc:0.70196	validation_0-aucpr:0.14946
# [10]	validation_0-auc:0.70786	validation_0-aucpr:0.15533
# [11]	validation_0-auc:0.70848	validation_0-aucpr:0.16450
# [12]	validation_0-auc:0.70629	validation_0-aucpr:0.16261
# [13]	validation_0-auc:0.70453	validation_0-aucpr:0.16121
# [14]	validation_0-auc:0.70259	validation_0-aucpr:0.15455
# [15]	validation_0-auc:0.70337	validation_0-aucpr:0.15334
# [16]	validation_0-auc:0.70383	validation_0-aucpr:0.15495
# [17]	validation_0-auc:0.69942	validation_0-aucpr:0.15540
# [18]	validation_0-auc:0.69697	validation_0-aucpr:0.15167
# [19]	validation_0-auc:0.70464	validation_0-aucpr:0.15328
# [20]	validation_0-auc:0.70534	validation_0-aucpr:0.15287
# [21]	validation_0-auc:0.70521	validation_0-aucpr:0.15125
# [22]	validation_0-auc:0.70587	validation_0-aucpr:0.15003
# [23]	validation_0-auc:0.70631	validation_0-aucpr:0.14937
# [24]	validation_0-auc:0.71179	validation_0-aucpr:0.15020
# [25]	validation_0-auc:0.71271	validation_0-aucpr:0.15129
# [26]	validation_0-auc:0.71473	validation_0-aucpr:0.15740
# [27]	validation_0-auc:0.71271	validation_0-aucpr:0.15860
# [28]	validation_0-auc:0.71505	validation_0-aucpr:0.15854
# [29]	validation_0-auc:0.71607	validation_0-aucpr:0.16114
# [30]	validation_0-auc:0.71808	validation_0-aucpr:0.15775
# [31]	validation_0-auc:0.72223	validation_0-aucpr:0.15746
# [32]	validation_0-auc:0.71865	validation_0-aucpr:0.15756
# [33]	validation_0-auc:0.71847	validation_0-aucpr:0.15653
# [34]	validation_0-auc:0.72128	validation_0-aucpr:0.15356
# [35]	validation_0-auc:0.71901	validation_0-aucpr:0.15140
# [36]	validation_0-auc:0.71879	validation_0-aucpr:0.15234
# [37]	validation_0-auc:0.71924	validation_0-aucpr:0.15307
# [38]	validation_0-auc:0.71789	validation_0-aucpr:0.15192
# [39]	validation_0-auc:0.71840	validation_0-aucpr:0.15203
# [40]	validation_0-auc:0.71630	validation_0-aucpr:0.15053
# [41]	validation_0-auc:0.71533	validation_0-aucpr:0.15073
# [42]	validation_0-auc:0.71648	validation_0-aucpr:0.15074
# [43]	validation_0-auc:0.71764	validation_0-aucpr:0.15103
# [44]	validation_0-auc:0.71834	validation_0-aucpr:0.15119
# [45]	validation_0-auc:0.71777	validation_0-aucpr:0.14929
# [46]	validation_0-auc:0.71399	validation_0-aucpr:0.14632
# [47]	validation_0-auc:0.71463	validation_0-aucpr:0.14766
# [48]	validation_0-auc:0.71526	validation_0-aucpr:0.14804
# [49]	validation_0-auc:0.71434	validation_0-aucpr:0.14751
# [50]	validation_0-auc:0.71501	validation_0-aucpr:0.14797
# [51]	validation_0-auc:0.71338	validation_0-aucpr:0.14750
# [52]	validation_0-auc:0.71595	validation_0-aucpr:0.14937
# [53]	validation_0-auc:0.71667	validation_0-aucpr:0.14878
# [54]	validation_0-auc:0.71625	validation_0-aucpr:0.14741
# [55]	validation_0-auc:0.71500	validation_0-aucpr:0.14717
# [56]	validation_0-auc:0.71486	validation_0-aucpr:0.14618
# [57]	validation_0-auc:0.71768	validation_0-aucpr:0.14587
# [58]	validation_0-auc:0.71792	validation_0-aucpr:0.14611
# [59]	validation_0-auc:0.71655	validation_0-aucpr:0.14600
# [60]	validation_0-auc:0.71840	validation_0-aucpr:0.14778
# [61]	validation_0-auc:0.71950	validation_0-aucpr:0.14831
# [62]	validation_0-auc:0.71963	validation_0-aucpr:0.14863
# [63]	validation_0-auc:0.71982	validation_0-aucpr:0.14769
# [64]	validation_0-auc:0.71953	validation_0-aucpr:0.14689
# [65]	validation_0-auc:0.71835	validation_0-aucpr:0.14675
# [66]	validation_0-auc:0.71946	validation_0-aucpr:0.14663
# [67]	validation_0-auc:0.71874	validation_0-aucpr:0.14645
# [68]	validation_0-auc:0.71912	validation_0-aucpr:0.14489
# [69]	validation_0-auc:0.71986	validation_0-aucpr:0.14561
# [70]	validation_0-auc:0.72005	validation_0-aucpr:0.14620
# [71]	validation_0-auc:0.71935	validation_0-aucpr:0.14594
# [72]	validation_0-auc:0.72013	validation_0-aucpr:0.14621
# [73]	validation_0-auc:0.72110	validation_0-aucpr:0.14623
# [74]	validation_0-auc:0.72008	validation_0-aucpr:0.14530
# [75]	validation_0-auc:0.72160	validation_0-aucpr:0.14503
# [76]	validation_0-auc:0.72157	validation_0-aucpr:0.14543
# [77]	validation_0-auc:0.72101	validation_0-aucpr:0.14495
# [78]	validation_0-auc:0.72094	validation_0-aucpr:0.14461
# [79]	validation_0-auc:0.72096	validation_0-aucpr:0.14423
# [80]	validation_0-auc:0.72096	validation_0-aucpr:0.14443
# [81]	validation_0-auc:0.72001	validation_0-aucpr:0.14359
# [82]	validation_0-auc:0.72150	validation_0-aucpr:0.14371
# [83]	validation_0-auc:0.72117	validation_0-aucpr:0.14300
# [84]	validation_0-auc:0.72202	validation_0-aucpr:0.14304
# [85]	validation_0-auc:0.72162	validation_0-aucpr:0.14285
# [86]	validation_0-auc:0.72123	validation_0-aucpr:0.14330
# [87]	validation_0-auc:0.72143	validation_0-aucpr:0.14391
# [88]	validation_0-auc:0.72089	validation_0-aucpr:0.14375
# [89]	validation_0-auc:0.72033	validation_0-aucpr:0.14373
# [90]	validation_0-auc:0.72084	validation_0-aucpr:0.14411
# [91]	validation_0-auc:0.72215	validation_0-aucpr:0.14488
# [92]	validation_0-auc:0.72325	validation_0-aucpr:0.14543
# [93]	validation_0-auc:0.72378	validation_0-aucpr:0.15024
# [94]	validation_0-auc:0.72346	validation_0-aucpr:0.15002
# [95]	validation_0-auc:0.72370	validation_0-aucpr:0.14996
# [96]	validation_0-auc:0.72435	validation_0-aucpr:0.14990
# [97]	validation_0-auc:0.72336	validation_0-aucpr:0.14926
# [98]	validation_0-auc:0.72334	validation_0-aucpr:0.14943
# [99]	validation_0-auc:0.72454	validation_0-aucpr:0.14930
# [100]	validation_0-auc:0.72405	validation_0-aucpr:0.14908
# [101]	validation_0-auc:0.72461	validation_0-aucpr:0.14884
# [102]	validation_0-auc:0.72435	validation_0-aucpr:0.14857
# [103]	validation_0-auc:0.72454	validation_0-aucpr:0.14861
# [104]	validation_0-auc:0.72413	validation_0-aucpr:0.14866
# [105]	validation_0-auc:0.72418	validation_0-aucpr:0.14925
# [106]	validation_0-auc:0.72489	validation_0-aucpr:0.14978
# [107]	validation_0-auc:0.72485	validation_0-aucpr:0.14975
# [108]	validation_0-auc:0.72516	validation_0-aucpr:0.14982
# [109]	validation_0-auc:0.72526	validation_0-aucpr:0.14994
# [110]	validation_0-auc:0.72459	validation_0-aucpr:0.14892
# [111]	validation_0-auc:0.72428	validation_0-aucpr:0.14865
# [112]	validation_0-auc:0.72415	validation_0-aucpr:0.14835
# [113]	validation_0-auc:0.72549	validation_0-aucpr:0.14863
# [114]	validation_0-auc:0.72590	validation_0-aucpr:0.14856
# [115]	validation_0-auc:0.72614	validation_0-aucpr:0.14809
# [116]	validation_0-auc:0.72631	validation_0-aucpr:0.14865
# [117]	validation_0-auc:0.72590	validation_0-aucpr:0.14798
# [118]	validation_0-auc:0.72551	validation_0-aucpr:0.14750
# [119]	validation_0-auc:0.72563	validation_0-aucpr:0.14754
# [120]	validation_0-auc:0.72486	validation_0-aucpr:0.14771
# [121]	validation_0-auc:0.72514	validation_0-aucpr:0.14865
# [122]	validation_0-auc:0.72522	validation_0-aucpr:0.14834
# [123]	validation_0-auc:0.72508	validation_0-aucpr:0.14816
# [124]	validation_0-auc:0.72590	validation_0-aucpr:0.14864
# [125]	validation_0-auc:0.72574	validation_0-aucpr:0.14845
# [126]	validation_0-auc:0.72615	validation_0-aucpr:0.14834
# [127]	validation_0-auc:0.72551	validation_0-aucpr:0.14725
# [128]	validation_0-auc:0.72593	validation_0-aucpr:0.14746
# [129]	validation_0-auc:0.72631	validation_0-aucpr:0.14831
# [130]	validation_0-auc:0.72650	validation_0-aucpr:0.14832
# [131]	validation_0-auc:0.72617	validation_0-aucpr:0.14796
# [132]	validation_0-auc:0.72666	validation_0-aucpr:0.14779
# [133]	validation_0-auc:0.72786	validation_0-aucpr:0.14871
# [134]	validation_0-auc:0.72774	validation_0-aucpr:0.14858
# [135]	validation_0-auc:0.72762	validation_0-aucpr:0.14859
# [136]	validation_0-auc:0.72768	validation_0-aucpr:0.14861
# [137]	validation_0-auc:0.72759	validation_0-aucpr:0.14829
# [138]	validation_0-auc:0.72762	validation_0-aucpr:0.14823
# [139]	validation_0-auc:0.72792	validation_0-aucpr:0.14807
# [140]	validation_0-auc:0.72770	validation_0-aucpr:0.14762
# [141]	validation_0-auc:0.72827	validation_0-aucpr:0.14787
# [142]	validation_0-auc:0.72837	validation_0-aucpr:0.14837
# [143]	validation_0-auc:0.72831	validation_0-aucpr:0.14815
# [144]	validation_0-auc:0.72851	validation_0-aucpr:0.14838
# [145]	validation_0-auc:0.72904	validation_0-aucpr:0.14858
# [146]	validation_0-auc:0.72948	validation_0-aucpr:0.14873
# [147]	validation_0-auc:0.72986	validation_0-aucpr:0.14905
# [148]	validation_0-auc:0.72986	validation_0-aucpr:0.14884
# [149]	validation_0-auc:0.73073	validation_0-aucpr:0.15002
# [150]	validation_0-auc:0.73004	validation_0-aucpr:0.14958
# [151]	validation_0-auc:0.72980	validation_0-aucpr:0.14892
# [152]	validation_0-auc:0.72941	validation_0-aucpr:0.14859
# [153]	validation_0-auc:0.72867	validation_0-aucpr:0.14851
# [154]	validation_0-auc:0.72909	validation_0-aucpr:0.14828
# [155]	validation_0-auc:0.72929	validation_0-aucpr:0.14816
# [156]	validation_0-auc:0.72962	validation_0-aucpr:0.14824
# [157]	validation_0-auc:0.72961	validation_0-aucpr:0.14807
# [158]	validation_0-auc:0.73051	validation_0-aucpr:0.14840
# [159]	validation_0-auc:0.73061	validation_0-aucpr:0.14423
# [160]	validation_0-auc:0.73051	validation_0-aucpr:0.14371
# [161]	validation_0-auc:0.73055	validation_0-aucpr:0.14389
# [162]	validation_0-auc:0.73052	validation_0-aucpr:0.14386
# [163]	validation_0-auc:0.73007	validation_0-aucpr:0.14368
# [164]	validation_0-auc:0.72972	validation_0-aucpr:0.14373
# [165]	validation_0-auc:0.72929	validation_0-aucpr:0.14326
# [166]	validation_0-auc:0.72927	validation_0-aucpr:0.14343
# [167]	validation_0-auc:0.72892	validation_0-aucpr:0.14360
# [168]	validation_0-auc:0.72851	validation_0-aucpr:0.14357
# [169]	validation_0-auc:0.72828	validation_0-aucpr:0.14362
# [170]	validation_0-auc:0.72821	validation_0-aucpr:0.14338
# [171]	validation_0-auc:0.72850	validation_0-aucpr:0.14351
# [172]	validation_0-auc:0.72845	validation_0-aucpr:0.14344
# [173]	validation_0-auc:0.72861	validation_0-aucpr:0.14400
# [174]	validation_0-auc:0.72865	validation_0-aucpr:0.14408
# [175]	validation_0-auc:0.72918	validation_0-aucpr:0.14461
# [176]	validation_0-auc:0.72928	validation_0-aucpr:0.14458
# [177]	validation_0-auc:0.72958	validation_0-aucpr:0.14405
# [178]	validation_0-auc:0.72961	validation_0-aucpr:0.14475
# [179]	validation_0-auc:0.72921	validation_0-aucpr:0.14410
# [180]	validation_0-auc:0.72915	validation_0-aucpr:0.14395
# [181]	validation_0-auc:0.72962	validation_0-aucpr:0.14404
# [182]	validation_0-auc:0.72944	validation_0-aucpr:0.14397
# [183]	validation_0-auc:0.72884	validation_0-aucpr:0.14349
# [184]	validation_0-auc:0.72826	validation_0-aucpr:0.14321
# [185]	validation_0-auc:0.72845	validation_0-aucpr:0.14346
# [186]	validation_0-auc:0.72841	validation_0-aucpr:0.14295
# [187]	validation_0-auc:0.72788	validation_0-aucpr:0.14248
# [188]	validation_0-auc:0.72752	validation_0-aucpr:0.14256
# [189]	validation_0-auc:0.72792	validation_0-aucpr:0.14253
# [190]	validation_0-auc:0.72777	validation_0-aucpr:0.14266
# [191]	validation_0-auc:0.72770	validation_0-aucpr:0.14270
# [192]	validation_0-auc:0.72733	validation_0-aucpr:0.14253
# [193]	validation_0-auc:0.72724	validation_0-aucpr:0.14232
# [194]	validation_0-auc:0.72733	validation_0-aucpr:0.14251
# [195]	validation_0-auc:0.72703	validation_0-aucpr:0.14228
# [196]	validation_0-auc:0.72722	validation_0-aucpr:0.14250
# [197]	validation_0-auc:0.72690	validation_0-aucpr:0.14240
# [198]	validation_0-auc:0.72686	validation_0-aucpr:0.14228
# [199]	validation_0-auc:0.72610	validation_0-aucpr:0.14215
# [200]	validation_0-auc:0.72606	validation_0-aucpr:0.14195
# [201]	validation_0-auc:0.72666	validation_0-aucpr:0.14216
# [202]	validation_0-auc:0.72635	validation_0-aucpr:0.14221
# [203]	validation_0-auc:0.72649	validation_0-aucpr:0.14225
# [204]	validation_0-auc:0.72632	validation_0-aucpr:0.14225
# [205]	validation_0-auc:0.72632	validation_0-aucpr:0.14227
# [206]	validation_0-auc:0.72677	validation_0-aucpr:0.14241
# [207]	validation_0-auc:0.72708	validation_0-aucpr:0.14249
# [208]	validation_0-auc:0.72727	validation_0-aucpr:0.14248
# [209]	validation_0-auc:0.72706	validation_0-aucpr:0.14251
# [210]	validation_0-auc:0.72714	validation_0-aucpr:0.14301
# [211]	validation_0-auc:0.72722	validation_0-aucpr:0.14748
# [212]	validation_0-auc:0.72726	validation_0-aucpr:0.14763
# [213]	validation_0-auc:0.72720	validation_0-aucpr:0.14278
# [214]	validation_0-auc:0.72684	validation_0-aucpr:0.14238
# [215]	validation_0-auc:0.72670	validation_0-aucpr:0.14236
# [216]	validation_0-auc:0.72661	validation_0-aucpr:0.14211
# [217]	validation_0-auc:0.72681	validation_0-aucpr:0.14214
# [218]	validation_0-auc:0.72660	validation_0-aucpr:0.14181
# [219]	validation_0-auc:0.72709	validation_0-aucpr:0.14190
# [220]	validation_0-auc:0.72718	validation_0-aucpr:0.14196
# [221]	validation_0-auc:0.72681	validation_0-aucpr:0.14150
# [222]	validation_0-auc:0.72734	validation_0-aucpr:0.14198
# [223]	validation_0-auc:0.72717	validation_0-aucpr:0.14175
# [224]	validation_0-auc:0.72730	validation_0-aucpr:0.14193
# [225]	validation_0-auc:0.72726	validation_0-aucpr:0.14182
# [226]	validation_0-auc:0.72716	validation_0-aucpr:0.14170
# [227]	validation_0-auc:0.72793	validation_0-aucpr:0.14223
# [228]	validation_0-auc:0.72777	validation_0-aucpr:0.14230
# [229]	validation_0-auc:0.72794	validation_0-aucpr:0.14229
# [230]	validation_0-auc:0.72765	validation_0-aucpr:0.14204
# [231]	validation_0-auc:0.72790	validation_0-aucpr:0.14232
# [232]	validation_0-auc:0.72767	validation_0-aucpr:0.14249
# [233]	validation_0-auc:0.72763	validation_0-aucpr:0.14262
# [234]	validation_0-auc:0.72727	validation_0-aucpr:0.14237
# [235]	validation_0-auc:0.72736	validation_0-aucpr:0.14282
# [236]	validation_0-auc:0.72713	validation_0-aucpr:0.14275
# [237]	validation_0-auc:0.72705	validation_0-aucpr:0.14266
# [238]	validation_0-auc:0.72735	validation_0-aucpr:0.14286
# [239]	validation_0-auc:0.72725	validation_0-aucpr:0.14719
# [240]	validation_0-auc:0.72751	validation_0-aucpr:0.14725
# [241]	validation_0-auc:0.72745	validation_0-aucpr:0.14709
# [242]	validation_0-auc:0.72774	validation_0-aucpr:0.14731
# [243]	validation_0-auc:0.72784	validation_0-aucpr:0.14745
# [244]	validation_0-auc:0.72780	validation_0-aucpr:0.14740
# [245]	validation_0-auc:0.72791	validation_0-aucpr:0.14292
# [246]	validation_0-auc:0.72810	validation_0-aucpr:0.14289
# [247]	validation_0-auc:0.72784	validation_0-aucpr:0.14278
# [248]	validation_0-auc:0.72824	validation_0-aucpr:0.14771
# [249]	validation_0-auc:0.72820	validation_0-aucpr:0.14738
# [250]	validation_0-auc:0.72843	validation_0-aucpr:0.14743
# [251]	validation_0-auc:0.72861	validation_0-aucpr:0.14786
# [252]	validation_0-auc:0.72849	validation_0-aucpr:0.14781
# [253]	validation_0-auc:0.72829	validation_0-aucpr:0.14781
# [254]	validation_0-auc:0.72855	validation_0-aucpr:0.14782
# [255]	validation_0-auc:0.72869	validation_0-aucpr:0.14803
# [256]	validation_0-auc:0.72862	validation_0-aucpr:0.14786
# [257]	validation_0-auc:0.72859	validation_0-aucpr:0.14772
# [258]	validation_0-auc:0.72890	validation_0-aucpr:0.14833
# [259]	validation_0-auc:0.72856	validation_0-aucpr:0.14789
# [260]	validation_0-auc:0.72812	validation_0-aucpr:0.14781
# [261]	validation_0-auc:0.72824	validation_0-aucpr:0.14771
# [262]	validation_0-auc:0.72834	validation_0-aucpr:0.14760
# [263]	validation_0-auc:0.72858	validation_0-aucpr:0.14788
# [264]	validation_0-auc:0.72860	validation_0-aucpr:0.14794
# [265]	validation_0-auc:0.72834	validation_0-aucpr:0.14779
# [266]	validation_0-auc:0.72855	validation_0-aucpr:0.14784
# [267]	validation_0-auc:0.72868	validation_0-aucpr:0.14783
# [268]	validation_0-auc:0.72874	validation_0-aucpr:0.14788
# [269]	validation_0-auc:0.72798	validation_0-aucpr:0.14757
# [270]	validation_0-auc:0.72793	validation_0-aucpr:0.14759
# [271]	validation_0-auc:0.72787	validation_0-aucpr:0.14802
# [272]	validation_0-auc:0.72742	validation_0-aucpr:0.14767
# [273]	validation_0-auc:0.72732	validation_0-aucpr:0.14728
# [274]	validation_0-auc:0.72774	validation_0-aucpr:0.14752
# [275]	validation_0-auc:0.72775	validation_0-aucpr:0.14778
# [276]	validation_0-auc:0.72741	validation_0-aucpr:0.14763
# [277]	validation_0-auc:0.72776	validation_0-aucpr:0.14831
# [278]	validation_0-auc:0.72786	validation_0-aucpr:0.14831
# [279]	validation_0-auc:0.72808	validation_0-aucpr:0.14885
# [280]	validation_0-auc:0.72805	validation_0-aucpr:0.14878
# [281]	validation_0-auc:0.72809	validation_0-aucpr:0.14879
# [282]	validation_0-auc:0.72839	validation_0-aucpr:0.14891
# [283]	validation_0-auc:0.72851	validation_0-aucpr:0.14901
# [284]	validation_0-auc:0.72838	validation_0-aucpr:0.14870
# [285]	validation_0-auc:0.72848	validation_0-aucpr:0.14849
# [286]	validation_0-auc:0.72848	validation_0-aucpr:0.14831
# [287]	validation_0-auc:0.72858	validation_0-aucpr:0.14836
# [288]	validation_0-auc:0.72868	validation_0-aucpr:0.14823
# [289]	validation_0-auc:0.72788	validation_0-aucpr:0.14765
# [290]	validation_0-auc:0.72777	validation_0-aucpr:0.14776
# [291]	validation_0-auc:0.72790	validation_0-aucpr:0.14797
# [292]	validation_0-auc:0.72796	validation_0-aucpr:0.14797
# [293]	validation_0-auc:0.72823	validation_0-aucpr:0.14816
# [294]	validation_0-auc:0.72808	validation_0-aucpr:0.14817
# [295]	validation_0-auc:0.72795	validation_0-aucpr:0.14747
# [296]	validation_0-auc:0.72818	validation_0-aucpr:0.14776
# [297]	validation_0-auc:0.72827	validation_0-aucpr:0.14788
# [298]	validation_0-auc:0.72834	validation_0-aucpr:0.14812
# [299]	validation_0-auc:0.72837	validation_0-aucpr:0.14818
# [300]	validation_0-auc:0.72848	validation_0-aucpr:0.14841
# [301]	validation_0-auc:0.72837	validation_0-aucpr:0.14838
# [302]	validation_0-auc:0.72840	validation_0-aucpr:0.14846
# [303]	validation_0-auc:0.72821	validation_0-aucpr:0.14858
# [304]	validation_0-auc:0.72839	validation_0-aucpr:0.14867
# [305]	validation_0-auc:0.72858	validation_0-aucpr:0.14889
# [306]	validation_0-auc:0.72877	validation_0-aucpr:0.14899
# [307]	validation_0-auc:0.72851	validation_0-aucpr:0.14881
# [308]	validation_0-auc:0.72870	validation_0-aucpr:0.14905
# [309]	validation_0-auc:0.72843	validation_0-aucpr:0.14875
# [310]	validation_0-auc:0.72892	validation_0-aucpr:0.14892
# [311]	validation_0-auc:0.72927	validation_0-aucpr:0.14938
# [312]	validation_0-auc:0.72936	validation_0-aucpr:0.14956
# [313]	validation_0-auc:0.72946	validation_0-aucpr:0.14937
# [314]	validation_0-auc:0.72931	validation_0-aucpr:0.14944
# [315]	validation_0-auc:0.72930	validation_0-aucpr:0.14946
# [316]	validation_0-auc:0.72894	validation_0-aucpr:0.14914
# [317]	validation_0-auc:0.72890	validation_0-aucpr:0.14915
# [318]	validation_0-auc:0.72892	validation_0-aucpr:0.14923
# [319]	validation_0-auc:0.72891	validation_0-aucpr:0.14951
# [320]	validation_0-auc:0.72866	validation_0-aucpr:0.14935
# [321]	validation_0-auc:0.72891	validation_0-aucpr:0.14952
# [322]	validation_0-auc:0.72873	validation_0-aucpr:0.14940
# [323]	validation_0-auc:0.72820	validation_0-aucpr:0.14925
# [324]	validation_0-auc:0.72833	validation_0-aucpr:0.14919
# [325]	validation_0-auc:0.72800	validation_0-aucpr:0.14893
# [326]	validation_0-auc:0.72801	validation_0-aucpr:0.14890
# [327]	validation_0-auc:0.72780	validation_0-aucpr:0.14888
# [328]	validation_0-auc:0.72804	validation_0-aucpr:0.14906
# [329]	validation_0-auc:0.72782	validation_0-aucpr:0.14909
# [330]	validation_0-auc:0.72798	validation_0-aucpr:0.14914
# [331]	validation_0-auc:0.72814	validation_0-aucpr:0.14907
# [332]	validation_0-auc:0.72831	validation_0-aucpr:0.14900
# [333]	validation_0-auc:0.72848	validation_0-aucpr:0.14912
# [334]	validation_0-auc:0.72853	validation_0-aucpr:0.14913
# [335]	validation_0-auc:0.72860	validation_0-aucpr:0.14903
# [336]	validation_0-auc:0.72865	validation_0-aucpr:0.14896
# [337]	validation_0-auc:0.72848	validation_0-aucpr:0.14849
# [338]	validation_0-auc:0.72862	validation_0-aucpr:0.14859
# [339]	validation_0-auc:0.72884	validation_0-aucpr:0.14869
# [340]	validation_0-auc:0.72869	validation_0-aucpr:0.14851
# [341]	validation_0-auc:0.72891	validation_0-aucpr:0.14872
# [342]	validation_0-auc:0.72904	validation_0-aucpr:0.14874
# [343]	validation_0-auc:0.72898	validation_0-aucpr:0.14892
# [344]	validation_0-auc:0.72878	validation_0-aucpr:0.14864
# [345]	validation_0-auc:0.72896	validation_0-aucpr:0.14873
# [346]	validation_0-auc:0.72898	validation_0-aucpr:0.14875
# [347]	validation_0-auc:0.72954	validation_0-aucpr:0.14911
# [348]	validation_0-auc:0.72958	validation_0-aucpr:0.14905
# [349]	validation_0-auc:0.72944	validation_0-aucpr:0.14885
# [350]	validation_0-auc:0.72938	validation_0-aucpr:0.14901
# [351]	validation_0-auc:0.72956	validation_0-aucpr:0.14901
# [352]	validation_0-auc:0.72971	validation_0-aucpr:0.14917
# [353]	validation_0-auc:0.72981	validation_0-aucpr:0.14920
# [354]	validation_0-auc:0.72970	validation_0-aucpr:0.14930
# [355]	validation_0-auc:0.72958	validation_0-aucpr:0.14930
# [356]	validation_0-auc:0.72974	validation_0-aucpr:0.14963
# [357]	validation_0-auc:0.72963	validation_0-aucpr:0.14969
# [358]	validation_0-auc:0.72942	validation_0-aucpr:0.14958
# [359]	validation_0-auc:0.72939	validation_0-aucpr:0.14959
# [360]	validation_0-auc:0.72937	validation_0-aucpr:0.14973
# [361]	validation_0-auc:0.72926	validation_0-aucpr:0.14953
# [362]	validation_0-auc:0.72957	validation_0-aucpr:0.14960
# [363]	validation_0-auc:0.72935	validation_0-aucpr:0.14958
# [364]	validation_0-auc:0.72958	validation_0-aucpr:0.14966
# [365]	validation_0-auc:0.72964	validation_0-aucpr:0.14986
# [366]	validation_0-auc:0.72980	validation_0-aucpr:0.14983
# [367]	validation_0-auc:0.73006	validation_0-aucpr:0.15003
# [368]	validation_0-auc:0.73014	validation_0-aucpr:0.15002
# [369]	validation_0-auc:0.73000	validation_0-aucpr:0.14983
# [370]	validation_0-auc:0.73016	validation_0-aucpr:0.14998
# [371]	validation_0-auc:0.73007	validation_0-aucpr:0.15005
# [372]	validation_0-auc:0.73000	validation_0-aucpr:0.15000
# [373]	validation_0-auc:0.72997	validation_0-aucpr:0.15007
# [374]	validation_0-auc:0.72979	validation_0-aucpr:0.14991
# [375]	validation_0-auc:0.72981	validation_0-aucpr:0.15037
# [376]	validation_0-auc:0.72975	validation_0-aucpr:0.15044
# [377]	validation_0-auc:0.72965	validation_0-aucpr:0.15037
# [378]	validation_0-auc:0.72958	validation_0-aucpr:0.15047
# [379]	validation_0-auc:0.72946	validation_0-aucpr:0.15026
# [380]	validation_0-auc:0.72890	validation_0-aucpr:0.14996
# [381]	validation_0-auc:0.72888	validation_0-aucpr:0.15004
# [382]	validation_0-auc:0.72895	validation_0-aucpr:0.15007
# [383]	validation_0-auc:0.72897	validation_0-aucpr:0.15005
# [384]	validation_0-auc:0.72846	validation_0-aucpr:0.14962
# [385]	validation_0-auc:0.72828	validation_0-aucpr:0.14939
# [386]	validation_0-auc:0.72799	validation_0-aucpr:0.14911
# [387]	validation_0-auc:0.72807	validation_0-aucpr:0.14915
# [388]	validation_0-auc:0.72806	validation_0-aucpr:0.14904
# [389]	validation_0-auc:0.72814	validation_0-aucpr:0.14912
# [390]	validation_0-auc:0.72787	validation_0-aucpr:0.14431
# [391]	validation_0-auc:0.72781	validation_0-aucpr:0.14426
# [392]	validation_0-auc:0.72766	validation_0-aucpr:0.14418
# [393]	validation_0-auc:0.72774	validation_0-aucpr:0.14481
# [394]	validation_0-auc:0.72804	validation_0-aucpr:0.14488
# [395]	validation_0-auc:0.72804	validation_0-aucpr:0.14960
# [396]	validation_0-auc:0.72771	validation_0-aucpr:0.14937
# [397]	validation_0-auc:0.72779	validation_0-aucpr:0.14939
# [398]	validation_0-auc:0.72771	validation_0-aucpr:0.14944
# [399]	validation_0-auc:0.72755	validation_0-aucpr:0.14936
# [400]	validation_0-auc:0.72732	validation_0-aucpr:0.14462
# [401]	validation_0-auc:0.72739	validation_0-aucpr:0.14438
# [402]	validation_0-auc:0.72734	validation_0-aucpr:0.14902
# [403]	validation_0-auc:0.72759	validation_0-aucpr:0.14914
# [404]	validation_0-auc:0.72745	validation_0-aucpr:0.14463
# [405]	validation_0-auc:0.72750	validation_0-aucpr:0.14946
# [406]	validation_0-auc:0.72763	validation_0-aucpr:0.14948
# [407]	validation_0-auc:0.72775	validation_0-aucpr:0.14959
# [408]	validation_0-auc:0.72778	validation_0-aucpr:0.14950
# [409]	validation_0-auc:0.72784	validation_0-aucpr:0.14934
# [410]	validation_0-auc:0.72769	validation_0-aucpr:0.14955
# [411]	validation_0-auc:0.72774	validation_0-aucpr:0.14972
# [412]	validation_0-auc:0.72805	validation_0-aucpr:0.14983
# [413]	validation_0-auc:0.72813	validation_0-aucpr:0.14989
# [414]	validation_0-auc:0.72836	validation_0-aucpr:0.14954
# [415]	validation_0-auc:0.72806	validation_0-aucpr:0.14942
# [416]	validation_0-auc:0.72781	validation_0-aucpr:0.14946
# [417]	validation_0-auc:0.72765	validation_0-aucpr:0.14972
# [418]	validation_0-auc:0.72753	validation_0-aucpr:0.14479
# [419]	validation_0-auc:0.72739	validation_0-aucpr:0.14506
# [420]	validation_0-auc:0.72738	validation_0-aucpr:0.14957
# [421]	validation_0-auc:0.72740	validation_0-aucpr:0.14976
# [422]	validation_0-auc:0.72727	validation_0-aucpr:0.14919
# [423]	validation_0-auc:0.72710	validation_0-aucpr:0.14904
# [424]	validation_0-auc:0.72742	validation_0-aucpr:0.14500
# [425]	validation_0-auc:0.72737	validation_0-aucpr:0.14961
# [426]	validation_0-auc:0.72743	validation_0-aucpr:0.14958
# [427]	validation_0-auc:0.72739	validation_0-aucpr:0.14490
# [428]	validation_0-auc:0.72718	validation_0-aucpr:0.14497
# [429]	validation_0-auc:0.72711	validation_0-aucpr:0.14505
# [430]	validation_0-auc:0.72699	validation_0-aucpr:0.14488
# [431]	validation_0-auc:0.72687	validation_0-aucpr:0.14476
# [432]	validation_0-auc:0.72675	validation_0-aucpr:0.14445
# [433]	validation_0-auc:0.72656	validation_0-aucpr:0.14448
# [434]	validation_0-auc:0.72634	validation_0-aucpr:0.14433
# [435]	validation_0-auc:0.72622	validation_0-aucpr:0.14436
# [436]	validation_0-auc:0.72621	validation_0-aucpr:0.14411
# [437]	validation_0-auc:0.72646	validation_0-aucpr:0.14446
# [438]	validation_0-auc:0.72666	validation_0-aucpr:0.14456
# [439]	validation_0-auc:0.72660	validation_0-aucpr:0.14458
# [440]	validation_0-auc:0.72663	validation_0-aucpr:0.14468
# [441]	validation_0-auc:0.72648	validation_0-aucpr:0.14467
# [442]	validation_0-auc:0.72633	validation_0-aucpr:0.14451
# [443]	validation_0-auc:0.72616	validation_0-aucpr:0.14429
# [444]	validation_0-auc:0.72629	validation_0-aucpr:0.14430
# [445]	validation_0-auc:0.72605	validation_0-aucpr:0.14445
# [446]	validation_0-auc:0.72617	validation_0-aucpr:0.14456
# [447]	validation_0-auc:0.72636	validation_0-aucpr:0.14473
# [448]	validation_0-auc:0.72619	validation_0-aucpr:0.14457
# [449]	validation_0-auc:0.72599	validation_0-aucpr:0.14427
# [450]	validation_0-auc:0.72587	validation_0-aucpr:0.14426
# [451]	validation_0-auc:0.72572	validation_0-aucpr:0.14424
# [452]	validation_0-auc:0.72600	validation_0-aucpr:0.14443
# [453]	validation_0-auc:0.72586	validation_0-aucpr:0.14440
# [454]	validation_0-auc:0.72608	validation_0-aucpr:0.14471
# [455]	validation_0-auc:0.72578	validation_0-aucpr:0.14456
# [456]	validation_0-auc:0.72593	validation_0-aucpr:0.14952
# [457]	validation_0-auc:0.72607	validation_0-aucpr:0.14967
# [458]	validation_0-auc:0.72581	validation_0-aucpr:0.14951
# [459]	validation_0-auc:0.72575	validation_0-aucpr:0.14944
# [460]	validation_0-auc:0.72582	validation_0-aucpr:0.14472
# [461]	validation_0-auc:0.72581	validation_0-aucpr:0.14392
# [462]	validation_0-auc:0.72592	validation_0-aucpr:0.14485
# [463]	validation_0-auc:0.72594	validation_0-aucpr:0.14973
# [464]	validation_0-auc:0.72603	validation_0-aucpr:0.14957
# [465]	validation_0-auc:0.72602	validation_0-aucpr:0.14968
# [466]	validation_0-auc:0.72587	validation_0-aucpr:0.14960
# [467]	validation_0-auc:0.72605	validation_0-aucpr:0.14970
# [468]	validation_0-auc:0.72578	validation_0-aucpr:0.14966
# [469]	validation_0-auc:0.72593	validation_0-aucpr:0.14976
# [470]	validation_0-auc:0.72581	validation_0-aucpr:0.14978
# [471]	validation_0-auc:0.72578	validation_0-aucpr:0.14977
# [472]	validation_0-auc:0.72580	validation_0-aucpr:0.14971
# [473]	validation_0-auc:0.72606	validation_0-aucpr:0.14990
# [474]	validation_0-auc:0.72610	validation_0-aucpr:0.14985
# [475]	validation_0-auc:0.72585	validation_0-aucpr:0.14410
# [476]	validation_0-auc:0.72588	validation_0-aucpr:0.14416
# [477]	validation_0-auc:0.72611	validation_0-aucpr:0.14419
# [478]	validation_0-auc:0.72611	validation_0-aucpr:0.14425
# [479]	validation_0-auc:0.72610	validation_0-aucpr:0.14452
# [480]	validation_0-auc:0.72605	validation_0-aucpr:0.14426
# [481]	validation_0-auc:0.72608	validation_0-aucpr:0.14434
# [482]	validation_0-auc:0.72607	validation_0-aucpr:0.14431
# [483]	validation_0-auc:0.72581	validation_0-aucpr:0.14414
# [484]	validation_0-auc:0.72574	validation_0-aucpr:0.14396
# [485]	validation_0-auc:0.72584	validation_0-aucpr:0.14409
# [486]	validation_0-auc:0.72563	validation_0-aucpr:0.14384
# [487]	validation_0-auc:0.72568	validation_0-aucpr:0.14382
# [488]	validation_0-auc:0.72558	validation_0-aucpr:0.14392
# [489]	validation_0-auc:0.72546	validation_0-aucpr:0.14362
# [490]	validation_0-auc:0.72524	validation_0-aucpr:0.14348
# [491]	validation_0-auc:0.72529	validation_0-aucpr:0.14343
# [492]	validation_0-auc:0.72521	validation_0-aucpr:0.14353
# [493]	validation_0-auc:0.72518	validation_0-aucpr:0.14325
# [494]	validation_0-auc:0.72471	validation_0-aucpr:0.14307
# [495]	validation_0-auc:0.72465	validation_0-aucpr:0.14288
# [496]	validation_0-auc:0.72444	validation_0-aucpr:0.14299
# [497]	validation_0-auc:0.72430	validation_0-aucpr:0.14293
# [498]	validation_0-auc:0.72422	validation_0-aucpr:0.14251
# [499]	validation_0-auc:0.72428	validation_0-aucpr:0.14271
# Round 001: Acc = 0.7586 | AUC = 0.6016 | AUC-PR = 0.1051 | TP = 518, FP = 2467, TN = 7546, FN = 99
# Round 002: Acc = 0.8423 | AUC = 0.6727 | AUC-PR = 0.1245 | TP = 515, FP = 1574, TN = 8439, FN = 102
# Round 003: Acc = 0.8444 | AUC = 0.6826 | AUC-PR = 0.1348 | TP = 531, FP = 1568, TN = 8445, FN = 86
# Round 004: Acc = 0.8599 | AUC = 0.6884 | AUC-PR = 0.1411 | TP = 540, FP = 1412, TN = 8601, FN = 77
# Round 005: Acc = 0.8679 | AUC = 0.6868 | AUC-PR = 0.1467 | TP = 547, FP = 1334, TN = 8679, FN = 70
# Round 006: Acc = 0.8748 | AUC = 0.6888 | AUC-PR = 0.1562 | TP = 551, FP = 1265, TN = 8748, FN = 66
# Round 007: Acc = 0.8836 | AUC = 0.6899 | AUC-PR = 0.1697 | TP = 554, FP = 1174, TN = 8839, FN = 63
# Round 008: Acc = 0.8817 | AUC = 0.6931 | AUC-PR = 0.1566 | TP = 559, FP = 1199, TN = 8814, FN = 58
# Round 009: Acc = 0.8851 | AUC = 0.7023 | AUC-PR = 0.1532 | TP = 552, FP = 1156, TN = 8857, FN = 65
# Round 010: Acc = 0.8891 | AUC = 0.7020 | AUC-PR = 0.1495 | TP = 555, FP = 1117, TN = 8896, FN = 62
# Round 011: Acc = 0.8897 | AUC = 0.7079 | AUC-PR = 0.1553 | TP = 553, FP = 1109, TN = 8904, FN = 64
# Round 012: Acc = 0.8929 | AUC = 0.7085 | AUC-PR = 0.1645 | TP = 551, FP = 1072, TN = 8941, FN = 66
# Round 013: Acc = 0.8981 | AUC = 0.7063 | AUC-PR = 0.1626 | TP = 558, FP = 1024, TN = 8989, FN = 59
# Round 014: Acc = 0.8983 | AUC = 0.7045 | AUC-PR = 0.1612 | TP = 564, FP = 1028, TN = 8985, FN = 53
# Round 015: Acc = 0.8983 | AUC = 0.7026 | AUC-PR = 0.1545 | TP = 568, FP = 1032, TN = 8981, FN = 49
# Round 016: Acc = 0.8963 | AUC = 0.7034 | AUC-PR = 0.1533 | TP = 568, FP = 1053, TN = 8960, FN = 49
# Round 017: Acc = 0.8989 | AUC = 0.7038 | AUC-PR = 0.1550 | TP = 574, FP = 1032, TN = 8981, FN = 43
# Round 018: Acc = 0.8988 | AUC = 0.6994 | AUC-PR = 0.1554 | TP = 570, FP = 1029, TN = 8984, FN = 47
# Round 019: Acc = 0.9007 | AUC = 0.6970 | AUC-PR = 0.1517 | TP = 572, FP = 1011, TN = 9002, FN = 45
# Round 020: Acc = 0.9017 | AUC = 0.7046 | AUC-PR = 0.1533 | TP = 570, FP = 998, TN = 9015, FN = 47
# Round 021: Acc = 0.9047 | AUC = 0.7053 | AUC-PR = 0.1529 | TP = 573, FP = 969, TN = 9044, FN = 44
# Round 022: Acc = 0.9057 | AUC = 0.7052 | AUC-PR = 0.1512 | TP = 572, FP = 957, TN = 9056, FN = 45
# Round 023: Acc = 0.9068 | AUC = 0.7059 | AUC-PR = 0.1500 | TP = 575, FP = 949, TN = 9064, FN = 42
# Round 024: Acc = 0.9073 | AUC = 0.7063 | AUC-PR = 0.1494 | TP = 578, FP = 946, TN = 9067, FN = 39
# Round 490: Acc = 0.9877 | AUC = 0.7255 | AUC-PR = 0.1436 | TP = 617, FP = 131, TN = 9882, FN = 0
# Round 491: Acc = 0.9876 | AUC = 0.7252 | AUC-PR = 0.1435 | TP = 617, FP = 132, TN = 9881, FN = 0
# Round 492: Acc = 0.9876 | AUC = 0.7253 | AUC-PR = 0.1434 | TP = 617, FP = 132, TN = 9881, FN = 0
# Round 493: Acc = 0.9878 | AUC = 0.7252 | AUC-PR = 0.1435 | TP = 617, FP = 130, TN = 9883, FN = 0
# Round 494: Acc = 0.9879 | AUC = 0.7252 | AUC-PR = 0.1433 | TP = 617, FP = 129, TN = 9884, FN = 0
# Round 495: Acc = 0.9878 | AUC = 0.7247 | AUC-PR = 0.1431 | TP = 617, FP = 130, TN = 9883, FN = 0
# Round 496: Acc = 0.9879 | AUC = 0.7246 | AUC-PR = 0.1429 | TP = 617, FP = 129, TN = 9884, FN = 0
# Round 497: Acc = 0.9877 | AUC = 0.7244 | AUC-PR = 0.1430 | TP = 617, FP = 131, TN = 9882, FN = 0
# Round 498: Acc = 0.9879 | AUC = 0.7243 | AUC-PR = 0.1429 | TP = 617, FP = 129, TN = 9884, FN = 0
# Round 499: Acc = 0.9881 | AUC = 0.7242 | AUC-PR = 0.1425 | TP = 617, FP = 127, TN = 9886, FN = 0
# Round 500: Acc = 0.9881 | AUC = 0.7243 | AUC-PR = 0.1427 | TP = 617, FP = 127, TN = 9886, FN = 0

# %% [markdown]
# # 2. HYPERPARAMETER TUNING
#  ALTHOUGH WE DO NOT USE CV, GridSearchCV IS USED FOR EASIER CODE MANAGEMENT AND MODULARITY

# %% [markdown]
# # 3. EVALUATE GENERALISATION PERFORMANCE (feel free to change this)

# %%
# =========================
# 3) EVALUATE (on held-out test)
# =========================
from sklearn.metrics import (
    average_precision_score,
    roc_auc_score,
    classification_report,
    accuracy_score
)

# ==== 9. Test Set Evaluation ====
DROP_COLS_TEST = [c for c in (ID_COLS + ["y"]) if c in test_df.columns]
Xte = test_df.drop(columns=DROP_COLS_TEST)
yte = test_df["y"].astype(int)

proba_te = pipe.predict_proba(Xte)[:, 1]
pred_te  = (proba_te >= 0.2).astype(int)

acc     = accuracy_score(yte, pred_te)
auc     = roc_auc_score(yte, proba_te)
aucpr   = average_precision_score(yte, proba_te)
clf_rep = classification_report(yte, pred_te, digits=3)

print("======  Test Set Evaluation ======")
print(f"[TEST] Accuracy  : {acc:.4f}")
print(f"[TEST] ROC-AUC   : {auc:.4f}")
print(f"[TEST] PR-AUC    : {aucpr:.4f}")
print("\n[TEST] Classification Report:")
print(clf_rep)
# Out:
# ====== 📊 Test Set Evaluation ======
# [TEST] Accuracy  : 0.8726
# [TEST] ROC-AUC   : 0.7118
# [TEST] PR-AUC    : 0.1580
#
# [TEST] Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.962     0.901     0.930      2131
#            1      0.179     0.377     0.243       122
#
#     accuracy                          0.873      2253
#    macro avg      0.570     0.639     0.587      2253
# weighted avg      0.920     0.873     0.893      2253
